# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('data/harvard_reviews.csv')

# %%
df.head()
# Out:
#               published_date published_platform  rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 2  2023-12-10T08:21:35-05:00             Mobile       3  review
# 3  2023-11-07T21:20:21-05:00            Desktop       4  review
# 4  2023-10-02T17:40:42-04:00            Desktop       5  review
#
#    helpful_votes                                              title  \
# 0              0                 Best classes and good environment
# 1              0                                 Harvard University
# 2              0                                 Walk around campus
# 3              0                     Interesting Harvard University
# 4              0  Lovely university campus has many historic and...
#
#                                                 text
# 0  Good thanks for everything good work group 👍 h...
# 1  Harvard University was founded in 1636 and is ...
# ...

# %%
df.describe()
# Out:
#             rating  helpful_votes
# count  3184.000000    3184.000000
# mean      4.456658       0.498744
# std       0.744024       2.819638
# min       1.000000       0.000000
# 25%       4.000000       0.000000
# 50%       5.000000       0.000000
# 75%       5.000000       1.000000
# max       5.000000     111.000000

# %%
df.isnull().value_counts()
# Out:
# published_date  published_platform  rating  type   helpful_votes  title  text
# False           False               False   False  False          False  False    3184
# Name: count, dtype: int64

# %%
df.dropna()
# Out:
#                  published_date published_platform  rating    type  \
# 0     2023-12-28T08:02:14-05:00             Mobile       5  review
# 1     2023-12-12T00:38:26-05:00            Desktop       4  review
# 2     2023-12-10T08:21:35-05:00             Mobile       3  review
# 3     2023-11-07T21:20:21-05:00            Desktop       4  review
# 4     2023-10-02T17:40:42-04:00            Desktop       5  review
# ...                         ...                ...     ...     ...
# 3179  2010-10-29T05:47:57-04:00            Desktop       3  review
# 3180  2010-08-23T06:08:51-04:00            Desktop       3  review
# 3181  2010-08-23T00:06:41-04:00            Desktop       5  review
# 3182  2010-06-03T07:37:36-04:00            Desktop       5  review
# 3183  2009-09-27T16:39:18-04:00            Desktop       5  review
#
#       helpful_votes                                              title  \
# 0                 0                 Best classes and good environment
# ...

# %%
df['type'].unique()
# Out:
# array(['review'], dtype=object)

# %%
df.loc[df['rating']>4, 'rating']
# Out:
# 0       5
# 4       5
# 6       5
# 7       5
# 11      5
#        ..
# 3176    5
# 3178    5
# 3181    5
# 3182    5
# 3183    5
# Name: rating, Length: 1852, dtype: int64

# %%
df.loc[df['title']=='Harvard University'].idxmax()
# Out:
# published_date           1
# published_platform      10
# rating                1506
# type                     1
# helpful_votes         2012
# title                    1
# text                  2232
# dtype: int64

# %%
df.head()
# Out:
#               published_date published_platform  rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 2  2023-12-10T08:21:35-05:00             Mobile       3  review
# 3  2023-11-07T21:20:21-05:00            Desktop       4  review
# 4  2023-10-02T17:40:42-04:00            Desktop       5  review
#
#    helpful_votes                                              title  \
# 0              0                 Best classes and good environment
# 1              0                                 Harvard University
# 2              0                                 Walk around campus
# 3              0                     Interesting Harvard University
# 4              0  Lovely university campus has many historic and...
#
#                                                 text
# 0  Good thanks for everything good work group 👍 h...
# 1  Harvard University was founded in 1636 and is ...
# ...

# %%
df.set_index('published_date', inplace=True)

# %%
df.head()
# Out:
#                           published_platform  rating    type  helpful_votes  \
# published_date
# 2023-12-28T08:02:14-05:00             Mobile       5  review              0
# 2023-12-12T00:38:26-05:00            Desktop       4  review              0
# 2023-12-10T08:21:35-05:00             Mobile       3  review              0
# 2023-11-07T21:20:21-05:00            Desktop       4  review              0
# 2023-10-02T17:40:42-04:00            Desktop       5  review              0
#
#                                                                        title  \
# published_date
# 2023-12-28T08:02:14-05:00                 Best classes and good environment
# 2023-12-12T00:38:26-05:00                                 Harvard University
# 2023-12-10T08:21:35-05:00                                 Walk around campus
# 2023-11-07T21:20:21-05:00                     Interesting Harvard University
# 2023-10-02T17:40:42-04:00  Lovely university campus has many historic and...
#
# ...
